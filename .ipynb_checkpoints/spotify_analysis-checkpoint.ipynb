# %%
import pandas as pd

data = pd.read_csv("regional-weekly-latest.csv", encoding = "ISO-8859-1")
data
# Out:
#       Position                 Track Name          Artist   Streams  \
# 0            1                  Heartless      The Weeknd  11224390
# 1            2                    ROXANNE  Arizona Zervas  10198981
# 2            3            Blinding Lights      The Weeknd   9583216
# 3            4                    Circles     Post Malone   7959651
# 4            5        everything i wanted   Billie Eilish   7130246
# ...        ...                        ...             ...       ...
# 6595       196         Heat (feat. Gunna)     Chris Brown     10175
# 6596       197  Bones (feat. OneRepublic)        Galantis     10073
# 6597       198      Panini - DaBaby Remix       Lil Nas X     10033
# 6598       199           Abuyile Amakhosi  Kabza De Small     10024
# 6599       200                     LaLaLa    Black Coffee      9990
#
#                                                     URL        Country
# 0     https://open.spotify.com/track/57vxBYXtHMk6H1a...  United States
# 1     https://open.spotify.com/track/696DnlkuDOXcMAn...  United States
# 2     https://open.spotify.com/track/0sf12qNH5qcw8qp...  United States
# 3     https://open.spotify.com/track/21jGcNKet2qwijl...  United States
# 4     https://open.spotify.com/track/3ZCTVFBt2Brf31R...  United States
# ...                                                 ...            ...
# 6595  https://open.spotify.com/track/1GIYmwtBbPSHrqc...   South Africa
# 6596  https://open.spotify.com/track/1pfgsjmxVZhoZpe...   South Africa
# 6597  https://open.spotify.com/track/4SDgTLDYrJ2UrHb...   South Africa
# 6598  https://open.spotify.com/track/09qyQr0PrUCB0V9...   South Africa
# 6599  https://open.spotify.com/track/0oL5c4N1W1x8i9H...   South Africa
#
# [6600 rows x 6 columns]

# %%
#tidying data
data = data.loc[data['Position'] <= 100]
#only use top 100 of each country

#rewriting some country names so they fit the properties for world countries json file that will be used later
data.loc[(data.Country == 'United States'),'Country']='United States of America'
data.loc[(data.Country == 'Portuagl'),'Country']='Portugal'
data
# Out:
#       Position                                       Track Name  \
# 0            1                                        Heartless
# 1            2                                          ROXANNE
# 2            3                                  Blinding Lights
# 3            4                                          Circles
# 4            5                              everything i wanted
# ...        ...                                              ...
# 6495        96                             lovely (with Khalid)
# 6496        97                                             Fire
# 6497        98                                          7 rings
# 6498        99                                  i'm so tired...
# 6499       100  ME! (feat. Brendon Urie of Panic! At The Disco)
#
#               Artist   Streams  \
# 0         The Weeknd  11224390
# 1     Arizona Zervas  10198981
# 2         The Weeknd   9583216
# 3        Post Malone   7959651
# 4      Billie Eilish   7130246
# ...              ...       ...
# 6495   Billie Eilish     15686
# 6496      DJ Big Sky     15551
# 6497   Ariana Grande     15449
# 6498            Lauv     15141
# 6499    Taylor Swift     15033
#
#                                                     URL  \
# 0     https://open.spotify.com/track/57vxBYXtHMk6H1a...
# 1     https://open.spotify.com/track/696DnlkuDOXcMAn...
# 2     https://open.spotify.com/track/0sf12qNH5qcw8qp...
# 3     https://open.spotify.com/track/21jGcNKet2qwijl...
# 4     https://open.spotify.com/track/3ZCTVFBt2Brf31R...
# ...                                                 ...
# 6495  https://open.spotify.com/track/0u2P5u6lvoDfwTY...
# 6496  https://open.spotify.com/track/2nVAnGGOKDTzCw5...
# 6497  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 6498  https://open.spotify.com/track/2iwS33Jfev1QBiu...
# 6499  https://open.spotify.com/track/2Rk4JlNc2TPmZe2...
#
#                        Country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 6495              South Africa
# 6496              South Africa
# 6497              South Africa
# 6498              South Africa
# 6499              South Africa
#
# [3300 rows x 6 columns]

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/conda/lib/python3.7/site-packages (2.4.4)
# Requirement already satisfied: requests>=1.0 in /opt/conda/lib/python3.7/site-packages (from spotipy) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=1.0->spotipy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=1.0->spotipy) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=1.0->spotipy) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=1.0->spotipy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

username = 'catherinelau.home@gmail.com'
scope = 'user-library-read'
client_id= "67820054fecc4ef887e50cd56a1247e2"
client_secret= "d25c2ed810844ca9a84fd127d8c7d3c0"
redirect_uri = 'https://www.google.com/'
token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)

# %%
import time
import numpy as np

danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []

sleep_min = 5
sleep_max = 10
start_time = time.time()
request_count = 0
track_count = 0
for track in data['URL']:
    features = sp.audio_features(track)
    if features[0] is None:
        danceability.append(None)
        energy.append(None)
        key.append(None)
        loudness.append(None)
        mode.append(None)
        speechiness.append(None)
        acousticness.append(None)
        instrumentalness.append(None)
        liveness.append(None)
        valence.append(None)
        tempo.append(None)
    else: 
        danceability.append(features[0]['danceability'])
        energy.append(features[0]['energy'])
        key.append(features[0]['key'])
        loudness.append(features[0]['loudness'])
        mode.append(features[0]['mode'])
        speechiness.append(features[0]['speechiness'])
        acousticness.append(features[0]['acousticness'])
        instrumentalness.append(features[0]['instrumentalness'])
        liveness.append(features[0]['liveness'])
        valence.append(features[0]['valence'])
        tempo.append(features[0]['tempo'])
    track_count+=1
    request_count+=1
    if request_count % 100 == 0:
        print(str(request_count) + " songs completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))

data['Danceability'] = danceability
data['Energy'] = energy
data['Key'] = key
data['Loudness'] = loudness
data['Mode'] = mode
data['Speechiness'] = speechiness
data['Acousticness'] = acousticness
data['Instrumentalness'] = instrumentalness
data['Liveness'] = liveness
data['Valence'] = valence
data['Tempo'] = tempo

    
data
# Out:
# 100 songs completed
# Loop #: 100
# Elapsed Time: 141.15318322181702 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0fd42bc824ba> in <module>
#      20 track_count = 0
#      21 for track in data['URL']:
# ---> 22     features = sp.audio_features(track)
#      23     if features[0] is None:
#      24         danceability.append(None)
#
# /opt/conda/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#     824         if isinstance(tracks, str):
#     825             trackid = self._get_id('track', tracks)
# --> 826             results = self._get('audio-features/?ids=' + trackid)
#     827         else:
#     828             tlist = [self._get_id('track', t) for t in tracks]
#
# /opt/conda/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# /opt/conda/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     601                                                   timeout=timeout_obj,
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#     605             # If we're going to release the connection in ``finally:``, then
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         # Trigger any extra validation we need to do.
#     343         try:
# --> 344             self._validate_conn(conn)
#     345         except (SocketTimeout, BaseSSLError) as e:
#     346             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     841         # Force connect early to allow us to validate the connection.
#     842         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 843             conn.connect()
#     844
#     845         if not conn.is_verified:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     314     def connect(self):
#     315         # Add certificate verification
# --> 316         conn = self._new_conn()
#     317         hostname = self.host
#     318
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#     162         except SocketTimeout:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
data = data.dropna()

# %%
# !pip install folium

# %%
#number of streams per country (folium map/heat map)
import folium
import requests
#list of all countries
countries = data['Country'].tolist()

country_geo = 'world-countries.json'

data_to_map = data[['Streams', 'Country']]
data_to_map = data_to_map.groupby('Country', as_index=False).sum()

streams_map = folium.Map(location=[0, 0], zoom_start=2)
streams_map.choropleth(geo_data=country_geo, data=data_to_map,
             columns=['Country', 'Streams'],
             key_on='feature.properties.name',
             fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
             legend_name='Number of Streams')


folium.LayerControl().add_to(streams_map)
streams_map

# %%
#danceability = how suitable a track is for dancing based on a combination of musical elements 
#including tempo, rhythm stability, beat strength, and overall regularity
#energy = perceptual measure of intensity and activity
#key = estimated overall key of the track
#loudness = overall loudness of a track in decibels (dB)
#mode = Mode indicates the modality (major or minor) of a track
#speechiness = 	Speechiness detects the presence of spoken words in a track
#acousticness = A confidence measure from 0.0 to 1.0 of whether the track is acoustic.
#instrumentalness = Predicts whether a track contains no vocals.
#liveness = Detects the presence of an audience in the recording.
#valence = 	A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track.
#tempo = The overall estimated tempo of a track in beats per minute (BPM).

# %%
#Factors that contribute to the success of a song
#make covariance matrix for feature selection and dimensionality reduction
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

#pair plots to show general relations between features
cols = ['Danceability', 'Energy', 'Key', 'Loudness', 'Mode','Speechiness',
        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo']
sns.pairplot(data[cols], height=3.0)
plt.show()

# %%
#quantifying degree of correlation using covariance matrix
cols = data[['Danceability', 'Energy', 'Key', 'Loudness', 'Mode','Speechiness',
        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo']]
plt.figure(figsize = (16,10))
sns.heatmap(cols.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
corr = cols.corr()
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if abs(corr.iloc[i,j]) > 0.4:
            if columns[j]:
                columns[j] = False
selected_columns = cols.columns[columns]
selected_columns

# %%
#combines streams of unique tracks throughout all countries
streams_data = data.groupby(['Track Name','Danceability', 'Energy', 'Key', 'Mode', 'Speechiness',
       'Instrumentalness', 'Liveness', 'Valence', 'Tempo'], as_index=False)['Streams'].sum()
streams_data

# %%
#features that are closely correlated with each other have a correlation coefficient of greater than 0.6
#To reduce the number of features we pick features that are not related so we can take into account of 
#features while limiting redundancy. Therefore we pick features with a correlation coefficient less than 0.6

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

y_array = np.array(streams_data['Streams'])
scaler = MinMaxScaler(feature_range = (0,1))
normalized_y = scaler.fit_transform(y_array.reshape(-1, 1)).flatten()
denormalized_y = scaler.inverse_transform(normalized_y.reshape(-1, 1)).flatten()

# %%
X = streams_data[selected_columns]
y = normalized_y 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
intercept = regression_model.intercept_
slope = regression_model.coef_
slope
print('Fitted model: y = ' + str(slope[0]) + 'a + ' + str(slope[1]) + 'b + '+ str(slope[2]) + 'c + '
     + str(slope[3]) + 'd + '+ str(slope[4]) + 'e + '+ str(slope[5]) + 'f + '+ str(slope[6]) + 'g + '
     + str(slope[7]) + 'h + ' + str(slope[8]) + 'i + '+ str(intercept))
#where a = danceability, b = energy, c = key, d = mode, e = speechiness, f = instrumentalness, g = liveness
#h = valence, and i = tempo

# %%
from sklearn.metrics import r2_score
print('R squared value: ', regression_model.score(X_train, y_train))

# %%
import matplotlib.pyplot as plt

predicted = regression_model.predict(X_test)
predicted = scaler.inverse_transform(predicted.reshape(-1, 1)).flatten()

actual = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

xx = list(range(len(actual))) # each song is a point on x axis

plt.rcParams["figure.figsize"] = [16,9]
plt.plot(xx, predicted, 'r.', label='predicted')
plt.plot(xx, actual, 'b.', label='actual')
plt.xlabel('Song')
plt.ylabel('Streams')
plt.legend()

# %%
diff = abs(actual - predicted)
diff = pd.Series(diff)
diff.hist(bins = 50)
#plt.xticks(range(0, int(max(diff)), 10**3))
plt.title('Histogram of prediction errors')
plt.xlabel('Prediction error')
plt.ylabel('Frequency')
