# %%
import pandas as pd

data = pd.read_csv("regional-weekly-latest.csv", encoding = "ISO-8859-1")
data.head(20)
# Out:
#     Position                                     Track Name          Artist  \
# 0          1                                      Heartless      The Weeknd
# 1          2                                        ROXANNE  Arizona Zervas
# 2          3                                Blinding Lights      The Weeknd
# 3          4                                        Circles     Post Malone
# 4          5                            everything i wanted   Billie Eilish
# 5          6                                        Falling   Trevor Daniel
# 6          7                            HIGHEST IN THE ROOM    Travis Scott
# 7          8                                            BOP          DaBaby
# 8          9                All I Want for Christmas Is You    Mariah Carey
# 9         10       Bandit (with YoungBoy Never Broke Again)      Juice WRLD
# 10        11                                   Dance Monkey     Tones and I
# ...
